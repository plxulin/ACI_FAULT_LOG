# %% [markdown]
# # Generate Final Result

# %% [markdown]
# ## Program Logic:
#
# ```pseudocode
#
# open("dest_excel")
# DataFrame(open("data_source"))
#
# for line in dest_excel:
#     target = specialtreat(line)
#     if  (target in data_source.xlsx) :
#         insert data_source[target] to dest_excel
#     else :
#         insert "not found" to dest_excel
#
# ```

# %%
import pandas as pd
import openpyxl

output  = pd.DataFrame()

# %%
source = pd.read_excel('test.xlsx')   # fault list from web 
dest = pd.read_excel('dest.xlsx')   #customer fault list

# %%
source
# Out:
#        Unnamed: 0      SN                                               Name  \
# 0               0   F0020               fltFabricSelectorIssuesConfig-failed
# 1               1   F0021      fltAaaRadiusProviderRadiusProvider_Inoperable
# 2               2   F0022          fltAaaLdapProviderLdapProvider_Inoperable
# 3               3   F0023   fltAaaTacacsPlusProviderTacacsPlusProvider_In...
# 4               4   F0048                fltStatsAExportJobIfc-export-failed
# ...           ...     ...                                                ...
# 52462       52462  F99883                   fltTcaEqptIngrBytes1dUnicastRate
# 52463       52463  F99884                   fltTcaEqptIngrBytes1wUnicastRate
# 52464       52464  F99885                  fltTcaEqptIngrBytes1moUnicastRate
# 52465       52465  F99886                 fltTcaEqptIngrBytes1qtrUnicastRate
# 52466       52466  F99887                fltTcaEqptIngrBytes1yearUnicastRate
#
#                                    Serverity  \
# 0         minor\n
# 1         minor\n
# 2         minor\n
# 3         minor\n
# 4         minor\n
# ...                                      ...
# 52462  variable\n
# 52463  variable\n
# 52464  variable\n
# 52465  variable\n
# 52466  variable\n
#
#                                              Explanation  \
# 0      This fault occurs when a fabric selector (port...
# 1      This fault occurs when the Radius Provider is ...
# 2      This fault occurs when the LDAP provider is no...
# 3      This fault occurs when the TACACS+ provider is...
# 4      This fault occurs due to a Stats Export Policy...
# ...                                                  ...
# 52462  This fault is caused by "Ingress Unicast Bytes...
# 52463  This fault is caused by "Ingress Unicast Bytes...
# 52464  This fault is caused by "Ingress Unicast Bytes...
# 52465  This fault is caused by "Ingress Unicast Bytes...
# 52466  This fault is caused by "Ingress Unicast Bytes...
#
#                                          ReconmandAction
# 0      Look at the configuration for issues\nFor inva...
# 1      Verify the IP address and path to the Radius p...
# 2      Verify the IP address and path to the LDAP pro...
# 3      Verify the IP address and path to the TACACS+ ...
# 4      If you see this fault, please check the Stats ...
# ...                                                  ...
# 52462  Check the values of "Ingress Unicast Bytes" st...
# 52463  Check the values of "Ingress Unicast Bytes" st...
# 52464  Check the values of "Ingress Unicast Bytes" st...
# 52465  Check the values of "Ingress Unicast Bytes" st...
# 52466  Check the values of "Ingress Unicast Bytes" st...
#
# [52467 rows x 6 columns]

# %%
dest
# Out:
#                                                  Alarms
# 0                  fltFabricSelectorIssuesConfig-failed
# 1         fltAaaRadiusProviderRadiusProvider_Inoperable
# 2             fltAaaLdapProviderLdapProvider_Inoperable
# 3         fltAaaTacacsPlusProviderTacacsPlusProvider...
# 4                   fltStatsAExportJobIfc-export-failed
# ...                                                 ...
# 1399                                         comp:RFltP
# 1400                  fsmFailCompRFltPAddorDelUsegRfltp
# 1401                                               FSMs
# 1402                                              Tasks
# 1403                                             Errors
#
# [1404 rows x 1 columns]

# %%
dest['Alarms'] = dest['Alarms'].apply(lambda x: x.split('\xa0')[-1])
source['Name'] = source['Name'].apply(lambda x: x.split()[-1])

# %%
dest = dest.rename(columns = {'Alarms':'Name'})
dest = dest.reindex(columns = ['Name','SN', 'Serverity', 'Explanation', 'ReconmandAction'])

# %%
for i in range(1404):
    s = source[source.Name == dest.loc[i].Name]
    try:
        dest.loc[i, 'SN'] = list(s.SN)[0]
    except:
        dest.loc[i, 'SN'] = 'None'
    try:
        dest.loc[i, 'Serverity'] = list(s.Serverity)[0]
    except:
        dest.loc[i, 'Serverity'] = 'None'
    try:
        dest.loc[i, 'Explanation'] = list(s.Explanation)[0]
    except:
        dest.loc[i, 'Explanation'] = 'None'
    try:
        dest.loc[i, 'ReconmandAction'] = list(s.ReconmandAction)[0]
    except:
        dest.loc[i, 'ReconmandAction'] = 'None'

# %%
dest.to_excel('result.xlsx')

# %%
dest
# Out:
#                                                    Name       SN  \
# 0                  fltFabricSelectorIssuesConfig-failed    F0020
# 1         fltAaaRadiusProviderRadiusProvider_Inoperable    F0021
# 2             fltAaaLdapProviderLdapProvider_Inoperable    F0022
# 3     fltAaaTacacsPlusProviderTacacsPlusProvider_Ino...    F0023
# 4                   fltStatsAExportJobIfc-export-failed    F0048
# ...                                                 ...      ...
# 1399                                         comp:RFltP     None
# 1400                  fsmFailCompRFltPAddorDelUsegRfltp  F608343
# 1401                                               FSMs     None
# 1402                                              Tasks     None
# 1403                                             Errors     None
#
#                                Serverity  \
# 0     minor\n
# 1     minor\n
# 2     minor\n
# 3     minor\n
# 4     minor\n
# ...                                  ...
# 1399                                None
# 1400  major\n
# 1401                                None
# 1402                                None
# 1403                                None
#
#                                             Explanation  \
# 0     This fault occurs when a fabric selector (port...
# 1     This fault occurs when the Radius Provider is ...
# 2     This fault occurs when the LDAP provider is no...
# 3     This fault occurs when the TACACS+ provider is...
# 4     This fault occurs due to a Stats Export Policy...
# ...                                                 ...
# 1399                                               None
# 1400  This fault is raised when adding/deleting micr...
# 1401                                               None
# 1402                                               None
# 1403                                               None
#
#                                         ReconmandAction
# 0     Look at the configuration for issues\nFor inva...
# 1     Verify the IP address and path to the Radius p...
# 2     Verify the IP address and path to the LDAP pro...
# 3     Verify the IP address and path to the TACACS+ ...
# 4     If you see this fault, please check the Stats ...
# ...                                                 ...
# 1399                                               None
# 1400  This task is automatically retried. If you see...
# 1401                                               None
# 1402                                               None
# 1403                                               None
#
# [1404 rows x 5 columns]

# %%
not_found = dest[dest.SN == 'None']

# %%
not_found.to_excel('not_found.xlsx')

# %% [markdown]
# ## END
